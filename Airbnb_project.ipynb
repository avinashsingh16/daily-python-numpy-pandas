# %% [markdown]
# <a href="https://colab.research.google.com/github/avinashsingh16/daily-python-numpy-pandas/blob/main/Airbnb_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/datasets/Airbnb NYC 2019.csv'

# %%
airbnb_df = pd.read_csv(path)

# %%
airbnb_df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
airbnb_df.shape
# Out:
# (48895, 16)

# %%
airbnb_df.columns
for col in airbnb_df.columns:
  print(airbnb_df[col].dtype)
# Out:
# int64
# object
# int64
# object
# object
# object
# float64
# float64
# object
# int64
# int64
# int64
# object
# float64
# int64
# int64

# %%
airbnb_df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
airbnb_df.head(10)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6  5121                                   BlissArtsSpace!     7356
# 7  5178                  Large Furnished Room Near B'way      8967
# 8  5203                Cozy Clean Guest Room - Family Apt     7490
# 9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0         John            Brooklyn          Kensington  40.64749  -73.97237
# ...

# %%
airbnb_df.tail()
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %% [markdown]
# **Selection and Filtering**

# %%
airbnb_df[airbnb_df['neighbourhood_group']=='Manhattan']
# Out:
#              id                                               name    host_id  \
# 1          2595                              Skylit Midtown Castle       2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099          Large Cozy 1 BR Apartment In Midtown East       7322
# 7          5178                   Large Furnished Room Near B'way        8967
# ...         ...                                                ...        ...
# 48886  36483010                    Comfy 1 Bedroom in Midtown East  274311461
# 48888  36484087  Spacious Room w/ Private Rooftop, Central loca...  274321313
# 48892  36485431            Sunny Studio at Historical Neighborhood   23492952
# 48893  36485609               43rd St. Time Square-cozy single bed   30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen   68119814
#
# ...

# %%
airbnb_df[(airbnb_df['room_type']=='Private room') & (airbnb_df['price']<100)]
# Out:
#              id                                               name    host_id  \
# 6          5121                                    BlissArtsSpace!       7356
# 7          5178                   Large Furnished Room Near B'way        8967
# 8          5203                 Cozy Clean Guest Room - Family Apt       7490
# 11         5441                    Central Manhattan/near Broadway       7989
# 12         5803     Lovely Room 1, Garden, Best Area, Legal rental       9744
# ...         ...                                                ...        ...
# 48885  36482809    Stunning Bedroom NYC! Walking to Central Park!!  131529729
# 48889  36484363                                 QUIT PRIVATE HOUSE  107716952
# 48890  36484665    Charming one bedroom - newly renovated rowhouse    8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg    6570630
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen   68119814
#
# ...

# %%
airbnb_df[airbnb_df['availability_365']>300]
# Out:
#              id                                               name    host_id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 1          2595                              Skylit Midtown Castle       2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 12         5803     Lovely Room 1, Garden, Best Area, Legal rental       9744
# 13         6021   Wonderful Guest Bedroom in Manhattan for SINGLES      11528
# ...         ...                                                ...        ...
# 48880  36481315  The Raccoon Artist Studio in Williamsburg New ...  208514239
# 48883  36482416       Sunny Bedroom NYC! Walking to Central Park!!  131529729
# 48884  36482783        Brooklyn Oasis in the heart of Williamsburg  274307600
# 48885  36482809    Stunning Bedroom NYC! Walking to Central Park!!  131529729
# 48887  36483152    Garden Jewel Apartment in Williamsburg New York  208514239
#
# ...

# %%
airbnb_df[airbnb_df['neighbourhood_group']=='Brooklyn'][['name','host_name','price']]
# Out:
#                                                   name      host_name  price
# 0                   Clean & quiet apt home by the park           John    149
# 3                      Cozy Entire Floor of Brownstone    LisaRoxanne     89
# 6                                      BlissArtsSpace!          Garon     60
# 12      Lovely Room 1, Garden, Best Area, Legal rental         Laurie     89
# 15                    Only 2 stops to Manhattan studio  Allen & Irina    140
# ...                                                ...            ...    ...
# 48882                        Bushwick _ Myrtle-Wyckoff          Luisa     40
# 48884      Brooklyn Oasis in the heart of Williamsburg       Jonathan    190
# 48887  Garden Jewel Apartment in Williamsburg New York          Melki    170
# 48890  Charming one bedroom - newly renovated rowhouse        Sabrina     70
# 48891    Affordable room in Bushwick/East Williamsburg        Marisol     40
#
# [20104 rows x 3 columns]

# %%
airbnb_df[airbnb_df['minimum_nights']>30]
# Out:
#              id                                               name    host_id  \
# 6          5121                                    BlissArtsSpace!       7356
# 14         6090                      West Village Nest - Superhost      11975
# 36        11452                        Clean and Quiet in Brooklyn       7355
# 61        15396                 Sunny & Spacious Chelsea Apartment      60278
# 81        19159               Spacious luminous apt Upper West NYC      73051
# ...         ...                                                ...        ...
# 48325  36204103         $2000 / Huge 1br - Cobble Hill | 8/1 start   95054582
# 48368  36224509   HUGE BEDROOM WITH PATIO ON HISTORIC LENOX AVE!!!     735287
# 48446  36270376     Beautiful home on Staten Island, walk to ferry     444904
# 48752  36417926  Room in Beautiful Duplex 4BR 2BA Nostrand av (...  272504878
# 48784  36426319  Duplex penthouse with terrace, prime UES location   46876102
#
# ...

# %% [markdown]
# **Handling Missing Data**

# %%
for col in airbnb_df.columns:
  if airbnb_df[col].isna().any():
    print(f"Missing values in column: {col}")
# Out:
# Missing values in column: name
# Missing values in column: host_name
# Missing values in column: last_review
# Missing values in column: reviews_per_month

# %%
airbnb_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
airbnb_df[airbnb_df['reviews_per_month'].isna()]
# Out:
#              id                                               name   host_id  \
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 19         7750                  Huge 2 BR Upper East  Cental Park     17985
# 26         8700  Magnifique Suite au N de Manhattan - vue Cloitres     26394
# 36        11452                        Clean and Quiet in Brooklyn      7355
# 38        11943                          Country space in the city     45445
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
airbnb_df['reviews_per_month'].fillna(0)
# Out:
# 0        0.21
# 1        0.38
# 2        0.00
# 3        4.64
# 4        0.10
#          ...
# 48890    0.00
# 48891    0.00
# 48892    0.00
# 48893    0.00
# 48894    0.00
# Name: reviews_per_month, Length: 48895, dtype: float64

# %%
airbnb_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
airbnb_df.dropna(subset=['host_name'],inplace=True)

# %%
airbnb_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# **Sorting**

# %%
airbnb_df.sort_values(by='price',ascending=False)
# Out:
#              id                                             name    host_id  \
# 9151    7003697              Furnished room in Astoria apartment   20582832
# 29238  22436899                              1-BR Lincoln Center   72390391
# 17692  13894339  Luxury 1 bedroom apt. -stunning Manhattan views    5143901
# 6530    4737930                               Spanish Harlem Apt    1235070
# 12342   9528920              Quiet, Clean, Lit @ LES & Chinatown    3906464
# ...         ...                                              ...        ...
# 26866  21304320           Best Coliving space ever! Shared room.  101970559
# 25753  20608117                  Sunny, Quiet Room in Greenpoint    1641537
# 25796  20639914     Cozy yet spacious private brownstone bedroom   86327101
# 26259  20933849                            the best you can find   13709292
# 25433  20333471    ★Hostel Style Room | Ideal Traveling Buddies★  131697576
#
# ...

# %%
airbnb_df.sort_values(by='number_of_reviews',ascending=False).head()
# Out:
#              id                            name   host_id host_name  \
# 11759   9145202         Room near JFK Queen Bed  47621202      Dona
# 2031     903972      Great Bedroom in Manhattan   4734398        Jj
# 2030     903947  Beautiful Bedroom in Manhattan   4734398        Jj
# 2015     891117    Private Bedroom in Manhattan   4734398        Jj
# 13495  10101135         Room Near JFK Twin Beds  47621202      Dona
#
#       neighbourhood_group neighbourhood  latitude  longitude     room_type  \
# 11759              Queens       Jamaica  40.66730  -73.76831  Private room
# 2031            Manhattan        Harlem  40.82085  -73.94025  Private room
# 2030            Manhattan        Harlem  40.82124  -73.93838  Private room
# 2015            Manhattan        Harlem  40.82264  -73.94041  Private room
# 13495              Queens       Jamaica  40.66939  -73.76975  Private room
#
#        price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# 🔢 Aggregation and GroupBy
#
# 	17.	What is the average price per neighbourhood_group?
#
# 	18.	Count the number of listings in each room_type.
#
# 	19.	Find the total availability (availability_365) for each neighbourhood_group.
#
# 	20.	What is the average minimum_nights for each room_type?

# %%
airbnb_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
airbnb_df.groupby('neighbourhood_group')['price'].mean()
# Out:
# neighbourhood_group
# Bronx             87.508257
# Brooklyn         124.398009
# Manhattan        196.895853
# Queens            99.536017
# Staten Island    114.812332
# Name: price, dtype: float64

# %%
airbnb_df.groupby('room_type').value_counts()
# Out:
# room_type        id        name                                              host_id    host_name    neighbourhood_group  neighbourhood   latitude  longitude  price  minimum_nights  number_of_reviews  last_review  reviews_per_month  calculated_host_listings_count  availability_365
# Entire home/apt  2595      Skylit Midtown Castle                             2845       Jennifer     Manhattan            Midtown         40.75362  -73.98377  225    1               45                 2019-05-21   0.38               2                               355                 1
#                  3831      Cozy Entire Floor of Brownstone                   4869       LisaRoxanne  Brooklyn             Clinton Hill    40.68514  -73.95976  89     1               270                2019-07-05   4.64               1                               194                 1
# ...

# %%
airbnb_df.groupby('neighbourhood_group')['availability_365'].size()
# Out:
# neighbourhood_group
# Bronx             1090
# Brooklyn         20095
# Manhattan        21652
# Queens            5664
# Staten Island      373
# Name: availability_365, dtype: int64

# %%
airbnb_df.groupby('room_type')['minimum_nights'].mean()
# Out:
# room_type
# Entire home/apt    8.507992
# Private room       5.379493
# Shared room        6.475000
# Name: minimum_nights, dtype: float64

# %% [markdown]
# 📊 Value Counts and Unique Values
#
# 	21.	How many unique neighbourhoods are there?
#
# 	22.	Show the count of each neighbourhood_group.
#
# 	23.	List all unique room_types.
#
# 	24.	How many hosts have more than 1 listing?
#
# ⸻

# %%
airbnb_df['neighbourhood'].value_counts()
# Out:
# neighbourhood
# Williamsburg          3919
# Bedford-Stuyvesant    3714
# Harlem                2656
# Bushwick              2464
# Upper West Side       1970
#                       ...
# Richmondtown             1
# Fort Wadsworth           1
# New Dorp                 1
# Rossville                1
# Willowbrook              1
# Name: count, Length: 221, dtype: int64

# %%
airbnb_df['neighbourhood_group'].value_counts()
# Out:
# neighbourhood_group
# Manhattan        21652
# Brooklyn         20095
# Queens            5664
# Bronx             1090
# Staten Island      373
# Name: count, dtype: int64

# %%
airbnb_df['room_type'].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
airbnb_df['']

# %%
airbnb_df.columns
(airbnb_df['host_name'].value_counts()>1).sum()
# Out:
# np.int64(4549)

# %% [markdown]
# 📅 Date Column Handling
#
# 	25.	Convert last_review to datetime.
#
# 	26.	What is the range of dates in last_review?
#
# 	27.	How many listings had their last review in 2019?
#
# 	28.	Filter listings that haven’t been reviewed (last_review is null).

# %%
airbnb_df['last_review'][0]
# Out:
# '2018-10-19'

# %%
from datetime import datetime
airbnb_df['last_review'] = pd.to_datetime(airbnb_df['last_review'])

# %%
min_date = airbnb_df['last_review'].min()
max_date = airbnb_df['last_review'].max()
print("Date range:", min_date,"to",max_date)
# Out:
# Date range: 2011-03-28 00:00:00 to 2019-07-08 00:00:00

# %%
df_2019 = airbnb_df[airbnb_df['last_review'].dt.year==2019]
print(len(df_2019))
# Out:
# 25201

# %%
airbnb_df[airbnb_df['last_review'].isna()]
# Out:
#              id                                               name   host_id  \
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 19         7750                  Huge 2 BR Upper East  Cental Park     17985
# 26         8700  Magnifique Suite au N de Manhattan - vue Cloitres     26394
# 36        11452                        Clean and Quiet in Brooklyn      7355
# 38        11943                          Country space in the city     45445
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# <a href="https://colab.research.google.com/github/avinashsingh16/daily-python-numpy-pandas/blob/main/Assignment_Pandas_Operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <u> Use only those concepts which have been taught till now </u>

# %% [markdown]
# # <b> Problem 1: Import Pandas and Numpy in the notebook </b>

# %%
# Import statements
import numpy as np
import pandas as pd

# %% [markdown]
# # <b> Problem 2 : Load the automobile_data.csv kept in the shared folder

# %%
# Mount your drive and read the csv file. Make sure you are using the correct file path
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/MyDrive/datasets/automobile_data.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# # <b> Problem 3 : Do a basic inspection and print the first and last 15 rows of your dataframe

# %%
# Your code here

df.head(60)
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3               NaN  alfa-romero       gas        std
# 1           3               NaN  alfa-romero       gas        std
# 2           1               NaN  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# 5           2               NaN         audi       gas        std
# 6           1               158         audi       gas        std
# 7           1               NaN         audi       gas        std
# 8           1               158         audi       gas      turbo
# 9           0               NaN         audi       gas      turbo
# 10          2               192          bmw       gas        std
# 11          0               192          bmw       gas        std
# 12          0               188          bmw       gas        std
# ...

# %%
df.tail(60)
# Out:
#      symboling normalized-losses        make fuel-type aspiration  \
# 145          0               102      subaru       gas      turbo
# 146          0                89      subaru       gas        std
# 147          0                89      subaru       gas        std
# 148          0                85      subaru       gas        std
# 149          0                85      subaru       gas      turbo
# 150          1                87      toyota       gas        std
# 151          1                87      toyota       gas        std
# 152          1                74      toyota       gas        std
# 153          0                77      toyota       gas        std
# 154          0                81      toyota       gas        std
# 155          0                91      toyota       gas        std
# 156          0                91      toyota       gas        std
# 157          0                91      toyota       gas        std
# ...

# %% [markdown]
# # <b>Problem 4 : You need to clean the data a little bit now. Replace all column values with the values <code>?</code> and <code>n.a</code> with <code>NaN</code>

# %%
# Your code here
data = pd.DataFrame(df)
df1 = data.replace(['?','n.a'],np.nan)
df1.head(15)
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3               NaN  alfa-romero       gas        std
# 1           3               NaN  alfa-romero       gas        std
# 2           1               NaN  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# 5           2               NaN         audi       gas        std
# 6           1               158         audi       gas        std
# 7           1               NaN         audi       gas        std
# 8           1               158         audi       gas      turbo
# 9           0               NaN         audi       gas      turbo
# 10          2               192          bmw       gas        std
# 11          0               192          bmw       gas        std
# 12          0               188          bmw       gas        std
# ...

# %% [markdown]
# # <b>Problem 5 : Print the company name which manufactured the most expensive car. Also print the price of the most expensive car

# %%
# Your code here
# data['price'] = pd.to_numeric(data['price'],errors='coerce')
expensive_car_company = data[data['price'] == data['price'].max()]
expensive_car_company['make']
# max_price = data['price'].max()
# max_price[3:4]
# Out:
# 74    mercedes-benz
# Name: make, dtype: object

# %% [markdown]
# # <b>Problem 6 : Calculate maximum horsepowers for each company. </b>

# %%
# Your code here
maker_company = data.groupby('make')['horsepower'].max()
maker_company
# Out:
# make
# alfa-romero      154
# audi             160
# bmw              182
# chevrolet         70
# dodge             88
# honda             86
# isuzu             90
# jaguar           262
# mazda             84
# mercedes-benz    184
# mercury          175
# mitsubishi        88
# nissan            97
# peugot            97
# plymouth          88
# porsche          288
# renault          NaN
# saab             160
# subaru            94
# toyota            92
# volkswagen        90
# volvo            162
# Name: horsepower, dtype: object

# %% [markdown]
# # <b> Problem 7 : Print the total number of cars manufactured by each company

# %%
# Your code here
data['make'].value_counts()
# Out:
# make
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# renault           2
# mercury           1
# Name: count, dtype: int64

# %% [markdown]
# # <b> Problem 8 : Create a new column for the updated price. This updated price will be calculated on top of the given price - if the engine is in front, price will be same else if the engine is in rear, price will be doubled </b>

# %%
# Your code here. Use apply and lambda
def updated_price(enginelocation,price):
  if enginelocation =='front':
    price = price
  else:
    price = price*2

  return price

data['updated_price'] = data.apply(lambda data:updated_price(data['engine-location'],data['price']),axis=1)

data.tail(50)
# Out:
#      symboling normalized-losses        make fuel-type aspiration  \
# 155          0                91      toyota       gas        std
# 156          0                91      toyota       gas        std
# 157          0                91      toyota       gas        std
# 158          0                91      toyota    diesel        std
# 159          0                91      toyota    diesel        std
# 160          0                91      toyota       gas        std
# 161          0                91      toyota       gas        std
# 162          0                91      toyota       gas        std
# 163          1               168      toyota       gas        std
# 164          1               168      toyota       gas        std
# 165          1               168      toyota       gas        std
# 166          1               168      toyota       gas        std
# 167          2               134      toyota       gas        std
# ...

# %% [markdown]
# # <b>Problem 9 : Sort the dataframe by car and price columns

# %%
# Your code here
data.sort_values(['make','price'],ascending=True)
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            3               NaN  alfa-romero       gas        std
# 2            1               NaN  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 5            2               NaN         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                74        volvo       gas      turbo
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %% [markdown]
# # <b> Problem 10 : Create a new column which stores the number of doors in a car as integers.

# %%
# Your code here. Use apply
def number_of_doors(numOfDoors):
  if numOfDoors =='two':
    return 2
  else:
    return 4

  return number_of_doors

data['number_of_doors'] = data['num-of-doors'].apply(number_of_doors)
# data.head(79)

# %% [markdown]
# # <b>Problem 11 : Concatenate the two data frames given below firstly row wise and secondly column wise.</b>
#
# <code>GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}</code>
#
# <code>japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}</code>

# %%
# Your code here
GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}
japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}
df1 = pd.DataFrame(GermanCars)
df2 = pd.DataFrame(japaneseCars)

# %%
# row-wise,by default it will be row
concat_row_wise = pd.concat([df1,df2])
concat_row_wise
# Out:
#        Company   Price
# 0         Ford   23845
# 1     Mercedes  171995
# 2          BMV  135925
# 3         Audi   71400
# 0       Toyota   29995
# 1        Honda   23600
# 2       Nissan   61500
# 3  Mitsubishi    58900

# %%
# column-wise,
concat_column_wise = pd.concat([df1,df2],axis=1)
concat_column_wise
# Out:
#     Company   Price      Company  Price
# 0      Ford   23845       Toyota  29995
# 1  Mercedes  171995        Honda  23600
# 2       BMV  135925       Nissan  61500
# 3      Audi   71400  Mitsubishi   58900

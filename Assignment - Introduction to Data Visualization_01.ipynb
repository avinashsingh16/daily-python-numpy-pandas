# %% [markdown]
# # <u> Use only those concepts which have been taught till now </u>

# %% [markdown]
# ## Use the file company_sales_data.csv

# %%
import numpy as np
import pandas as pd

from datetime import datetime

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('company_sales_data.csv')

# %%
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
df.shape
# Out:
# (12, 9)

# %% [markdown]
# # <u>**Problem 1**</u>
#
# ### Plot the total profit across the months
#
# * X label name = Month Number
# * Y label name = Total profit

# %%
plt.plot(df['month_number'],df['total_profit'],marker='o')
plt.title('Monthly Profit')
plt.xlabel('Month')
plt.ylabel('Total Profit')

# plt.xticks(ticks=df['month_number'])
# plt.yticks(ticks=df['total_profit'])
plt.show()

# %% [markdown]
# # <b><u>Problem 2 </u></b>
#
# ### Read face cream and facewash product sales data and show it using the bar chart. The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.

# %%
# Your code here
# set the width of the bar
bar_width = 0.25

# set the positions of the bar on x-axis
a = range(len(df)) # x-position for face cream
b = [x+bar_width for x in a] # x-position for facewash

# create a bar chart for facewash and face cream
plt.bar(a,df['facecream'],color='skyblue',width=bar_width,edgecolor='black',label='facecream')
plt.bar(b,df['facewash'],color='red',width=bar_width,edgecolor='black',label='facewash')

# add labels and title
plt.title('Facewash and facecream sold per month')
plt.xlabel('Month')
plt.ylabel('Amount')

#add a legend
plt.legend()

#Display the plot
plt.show()

# %% [markdown]
# # <b><u>Problem 3</u></b>
#
# ### Display the number of units sold per month for each product using multiline plots. (i.e. separate plotline for each product ).

# %%
df.head(1)
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000

# %%
# Your code here
# Plot for each product
plt.plot(df['month_number'],df['facecream'],label='facecream',marker='o')
plt.plot(df['month_number'],df['facewash'],label='facewash',marker='o')
plt.plot(df['month_number'],df['toothpaste'],label='toothpaste',marker='o')
plt.plot(df['month_number'],df['bathingsoap'],label='bathingsoap',marker='o')
plt.plot(df['month_number'],df['shampoo'],label='shampoo',marker='o')
plt.plot(df['month_number'],df['moisturizer'],label='moisturizer',marker='o')
plt.plot(df['month_number'],df['moisturizer'],label='moisturizer',marker='o')

#adding titles and labels
plt.title("Monthly sales for different product")
plt.xlabel("Month")
plt.ylabel("Unit sold")

# display the legend
plt.legend()

#show the plot
plt.show()
